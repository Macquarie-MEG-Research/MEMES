# %%
import mne
# Out:
# /Users/44737483/Documents/Anaconda/anaconda/envs/py35/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import numpy as np

# %%
rawfile = '/Users/44737483/Documents/scripts_mcq/RS_elekta/rs_asd_rs_aliens_quat_tsss.fif'
raw = mne.io.read_raw_fif(rawfile, preload=True)
# Out:
# Opening raw data file /Users/44737483/Documents/scripts_mcq/RS_elekta/rs_asd_rs_aliens_quat_tsss.fif...
# This filename (/Users/44737483/Documents/scripts_mcq/RS_elekta/rs_asd_rs_aliens_quat_tsss.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
# <ipython-input-5-799114723edc>:2: RuntimeWarning: This filename (/Users/44737483/Documents/scripts_mcq/RS_elekta/rs_asd_rs_aliens_quat_tsss.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   raw = mne.io.read_raw_fif(rawfile, preload=True)
#     Range : 13000 ... 822999 =     13.000 ...   822.999 secs
# Ready.
# Current compensation grade : 0
# Reading 0 ... 809999  =      0.000 ...   809.999 secs...

# %%
events = mne.find_events(raw,uint_cast=True,initial_event=True)
# Out:
# Trigger channel has a non-zero initial value of 2048 (consider using initial_event=True to detect this event)
# 323 events found
# Event IDs: [2049 2050 2052 2056 2064 2080 2088 3072 3074]

# %%
events
# Out:
# array([[ 16128,   2048,   2050],
#        [ 19647,   2048,   2064],
#        [ 21784,   2048,   3072],
#        [ 23048,   2048,   2049],
#        [ 25566,   2048,   2064],
#        [ 29852,   2048,   2056],
#        [ 31352,   2056,   2088],
#        [ 33361,   2048,   3072],
#        [ 34654,   2048,   2050],
#        [ 36171,   2048,   2064],
#        [ 38177,   2048,   3072],
#        [ 39456,   2048,   2052],
#        [ 42989,   2048,   2080],
#        [ 47276,   2048,   2052],
#        [ 49822,   2048,   2080],
#        [ 54130,   2048,   2049],
#        [ 55647,   2048,   2064],
#        [ 59932,   2048,   2056],
#        [ 63471,   2048,   2080],
#        [ 65376,   2048,   3072],
#        [ 66652,   2048,   2049],
#        [ 70170,   2048,   2064],
#        [ 74472,   2048,   2050],
#        [ 77991,   2048,   2064],
#        [ 79876,   2048,   3072],
#        [ 81142,   2048,   2056],
#        [ 84678,   2048,   2080],
#        [ 86560,   2048,   3072],
# ...

# %%
list(events[:,2]).count(16)
# Out:
# 0

# %%
raw._data[chan, :] = 255 - raw._data[chan, :]

# %%
3072%256
# Out:
# 0

# %%
event_id = dict(visual=16, auditory=32)  # event trigger and conditions
epochs = mne.Epochs(raw, events, event_id, tmin=-2, tmax=2,
                    baseline=(None, 0), preload=True)
# Out:
# 127 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 127 events and 4001 original time points ...
# 0 bad epochs dropped

# %%
events
# Out:
# array([[     0,      0,   2048],
#        [ 16128,   2048,   2050],
#        [ 19647,   2048,   2064],
#        [ 21784,   2048,   3072],
#        [ 23048,   2048,   2049],
#        [ 25566,   2048,   2064],
#        [ 29852,   2048,   2056],
#        [ 31352,   2056,   2088],
#        [ 33361,   2048,   3072],
#        [ 34654,   2048,   2050],
#        [ 36171,   2048,   2064],
#        [ 38177,   2048,   3072],
#        [ 39456,   2048,   2052],
#        [ 42989,   2048,   2080],
#        [ 47276,   2048,   2052],
#        [ 49822,   2048,   2080],
#        [ 54130,   2048,   2049],
#        [ 55647,   2048,   2064],
#        [ 59932,   2048,   2056],
#        [ 63471,   2048,   2080],
#        [ 65376,   2048,   3072],
#        [ 66652,   2048,   2049],
#        [ 70170,   2048,   2064],
#        [ 74472,   2048,   2050],
#        [ 77991,   2048,   2064],
#        [ 79876,   2048,   3072],
#        [ 81142,   2048,   2056],
#        [ 84678,   2048,   2080],
# ...

# %%
2048%256
# Out:
# 0

# %%
chan = np.where(np.array(raw.ch_names) == 'STI_101')[0]
raw._data[chan, :] *= -1
